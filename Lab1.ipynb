# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import io
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/lung_cancer.csv")

# %%
df.columns
# Out:
# Index(['Name', 'Surname', 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'], dtype='object')

# %%
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %% [markdown]
# Relationship with Age and Result based on people with Smoke Habbit

# %%
sns.lineplot(x='Age',y='Result',data=df)

# %% [markdown]
# Relationship with Age and Result based on people with Alkhol Habbit

# %%
sns.lineplot(x='Age',y='Result',data=df)

# %% [markdown]
# Relationship between 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'

# %%
sns.pairplot(data=df)

# %% [markdown]
# Relationship between Age and Alkhol

# %%
plt.figure(figsize=(50, 10))
g=sns.barplot(x='Age',y='Alkhol',data=df)

# %% [markdown]
# Distribution of Age with Cancer positive result

# %%
df1 = df[df.Result==1]
sns.distplot(df1.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df2 = df[df.Result==0]
sns.distplot(df2.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(data=df[['Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result']],cmap="YlGnBu")

# %%
sns.scatterplot(x="Age", y="Smokes", data=df)

# %%
sns.scatterplot(x="Age", y="Result",
                      hue="Smokes",
                      data=df)

# %%
plt.figure(figsize=(50, 20))
sns.violinplot(x='Age',y='Result',data=df)

# %%
df.boxplot(grid="false", color="red", fontsize=12, rot=50)

# %%
sns.histplot(df2.Age)

# %%
joinpt = df[df.Smokes>3]
joinpt2 = df[df.AreaQ>3]
sns.jointplot(joinpt.Age, joinpt2.AreaQ)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.stripplot(joinpt.Age, joinpt2.AreaQ)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f,ax=plt.subplots(figsize=(4,4))
plt.pie(df["Age"].value_counts().tolist(),
        labels=["xxx","yyy","zzz","aaa"],
        autopct='%1.1f%%',startangle=90)
axis = plt.axis('equal')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-27d4906e1fda> in <module>()
#       9 plt.pie(df["Age"].value_counts().tolist(),
#      10         labels=["xxx","yyy","zzz","aaa"],
# ---> 11         autopct='%1.1f%%',startangle=90)
#      12 axis = plt.axis('equal')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2927             explode = [0] * len(x)
#    2928         if len(x) != len(labels):
# -> 2929             raise ValueError("'label' must be of length 'x'")
#    2930         if len(x) != len(explode):
#    2931             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
